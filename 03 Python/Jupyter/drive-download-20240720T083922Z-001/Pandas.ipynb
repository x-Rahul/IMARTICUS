# %%
# Pandas - Data manipulation

# %%
import pandas as pd
import numpy as np
import os  # connection python to you local machine

# %%
# Direct through machine
sale=pd.read_csv(r"C:/Users/HP/Desktop/DS/PGA44/EDA/Car_sales.csv")

# %%
sale.head(4)
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger                21.5          1.8       140.0      101.2   67.3
# 1    Passenger                28.4          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger                42.0          3.5       210.0      114.6   71.4
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0   172.4        2.639           13.2             28.0      2/2/2012
# 1   192.9        3.517           17.2             25.0      6/3/2011
# ...

# %%
os.chdir(r"C:\Users\HP\Desktop\DS\PGA44\EDA")

# %%
os.listdir() # list down all the files available in the directory
# Out:
# ['abc.csv',
#  'Car_sales.csv',
#  'Churn_Modelling.csv',
#  'Global Superstore (1).xls']

# %%
h=pd.read_csv("Churn_Modelling.csv")
h.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
g=pd.read_csv("Car_sales.csv")
g.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
j=pd.read_excel("Global Superstore (1).xls")
j.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# ### Explore tha Data

# %%
sale.head()  # diplay 5 rows from the beginning, NaN- Missing Value
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sale.head(10)  # here 10 row will displayed from beginning
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
# 5         Audi       A6              18.780                  23.555
# 6         Audi       A8               1.380                  39.000
# 7          BMW     323i              19.747                     NaN
# 8          BMW     328i               9.231                  28.675
# 9          BMW     528i              17.527                  36.125
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# ...

# %%
sale.tail()  # 5 rows from bottom
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 152        Volvo   V40               3.545                     NaN
# 153        Volvo   S70              15.245                     NaN
# 154        Volvo   V70              17.531                     NaN
# 155        Volvo   C70               3.493                     NaN
# 156        Volvo   S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 152    Passenger                24.4          1.9       160.0      100.5
# 153    Passenger                27.5          2.4       168.0      104.9
# 154    Passenger                28.8          2.4       168.0      104.9
# 155    Passenger                45.5          2.3       236.0      104.9
# 156    Passenger                36.0          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sale.tail(2)
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 155        Volvo   C70               3.493                     NaN
# 156        Volvo   S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 155    Passenger                45.5          2.3       236.0      104.9
# 156    Passenger                36.0          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 155   71.5   185.7        3.601           18.5             23.0     4/26/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 155         101.623357
# 156          85.735655

# %%
sale  # printing all records - only 5 from beginning and 5 from bottom will be displayed
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                     NaN
# 153        Volvo      S70              15.245                     NaN
# 154        Volvo      V70              17.531                     NaN
# 155        Volvo      C70               3.493                     NaN
# 156        Volvo      S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
sale.shape   # (Rows, Columns)
# Out:
# (157, 16)

# %%
sale.columns  # column Names
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
sale.index  # rows
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
sale.dtypes  # Data type of each column object (string), number, datetime
# Out:
# Manufacturer               object
# Model                      object
# Sales_in_thousands        float64
# four_year_resale_value    float64
# Vehicle_type               object
# Price_in_thousands        float64
# Engine_size               float64
# Horsepower                float64
# Wheelbase                 float64
# Width                     float64
# Length                    float64
# Curb_weight               float64
# Fuel_capacity             float64
# Fuel_efficiency           float64
# Latest_Launch              object
# Power_perf_factor         float64
# dtype: object

# %%
sale.info()  # Detailed exploration of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturer            157 non-null    object
#  1   Model                   157 non-null    object
#  2   Sales_in_thousands      157 non-null    float64
#  3   four_year_resale_value  121 non-null    float64
#  4   Vehicle_type            157 non-null    object
#  5   Price_in_thousands      155 non-null    float64
#  6   Engine_size             156 non-null    float64
#  7   Horsepower              156 non-null    float64
#  8   Wheelbase               156 non-null    float64
#  9   Width                   156 non-null    float64
#  10  Length                  156 non-null    float64
#  11  Curb_weight             155 non-null    float64
#  12  Fuel_capacity           156 non-null    float64
#  13  Fuel_efficiency         154 non-null    float64
# ...

# %%
# Subset of data 
    # 1. Row subset 
    # 2. Column subset
    # 3. row and column subset
    # 4. conditional subsetting
# Sampling
# Creating new columns
# Deleting columns
# Duplicate check and remove
# Missing Value identification and treatment 
# Sorting -(order by - acending or descending )
# Renaming of the columns
# Indexing - changing index
# Merging, concate and appending 
# Basic statistics - mean, median , mode, sum , count, std, variance, etc...
# Summary - pivot table, group by , 
# Graphs - Plotting - bar, pie , histogram etc..
# Saving the data to location

# %% [markdown]
# #### Subset of data

# %%
sale.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
sale.Price_in_thousands  # extract only single column
# Out:
# 0      21.50
# 1      28.40
# 2        NaN
# 3      42.00
# 4      23.99
#        ...
# 152    24.40
# 153    27.50
# 154    28.80
# 155    45.50
# 156    36.00
# Name: Price_in_thousands, Length: 157, dtype: float64

# %%
sale["Price_in_thousands"]  # extract only one column - method2
# Out:
# 0      21.50
# 1      28.40
# 2        NaN
# 3      42.00
# 4      23.99
#        ...
# 152    24.40
# 153    27.50
# 154    28.80
# 155    45.50
# 156    36.00
# Name: Price_in_thousands, Length: 157, dtype: float64

# %%
j.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
j.Ship Date # it can not be extracted as it has space in the name ( Special character)
# Out:
#   Cell In[25], line 1
#     j.Ship Date # it can not be extracted as it has space in the name ( Special character)
#            ^
# SyntaxError: invalid syntax

# %%
j["Ship Date"]
# Out:
# 0       2012-07-31
# 1       2013-02-07
# 2       2013-10-18
# 3       2013-01-30
# 4       2013-11-06
#            ...
# 51285   2014-06-19
# 51286   2014-06-24
# 51287   2013-12-02
# 51288   2012-02-22
# 51289   2012-05-26
# Name: Ship Date, Length: 51290, dtype: datetime64[ns]

# %%
# Extract 2 or more than 2 columns

# %%
sale[["Manufacturer", "Sales_in_thousands", "Engine_size"]]
# Out:
#     Manufacturer  Sales_in_thousands  Engine_size
# 0          Acura              16.919          1.8
# 1          Acura              39.384          3.2
# 2          Acura              14.114          3.2
# 3          Acura               8.588          3.5
# 4           Audi              20.397          1.8
# ..           ...                 ...          ...
# 152        Volvo               3.545          1.9
# 153        Volvo              15.245          2.4
# 154        Volvo              17.531          2.4
# 155        Volvo               3.493          2.3
# 156        Volvo              18.969          2.9
#
# [157 rows x 3 columns]

# %%
# row and column extract

# %%
# data.loc[row label, column label]  # It takes label as input to extract the row and columns
# data.iloc[row index, column index] # It takes index as input to extract the row and columns

# %%
sale.head(10)
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
# 5         Audi       A6              18.780                  23.555
# 6         Audi       A8               1.380                  39.000
# 7          BMW     323i              19.747                     NaN
# 8          BMW     328i               9.231                  28.675
# 9          BMW     528i              17.527                  36.125
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# ...

# %%
sale.iloc[4,1]  #  fourth index row and first index columns
# Out:
# 'A4'

# %%
sale.iloc[4, 1:4] # fourth index row and 1to 4th columns
# Out:
# Model                         A4
# Sales_in_thousands        20.397
# four_year_resale_value    22.255
# Name: 4, dtype: object

# %%
sale.iloc[3:7, 1:4]
# Out:
#   Model  Sales_in_thousands  four_year_resale_value
# 3    RL               8.588                  29.725
# 4    A4              20.397                  22.255
# 5    A6              18.780                  23.555
# 6    A8               1.380                  39.000

# %%
sale.iloc[[4,7,10,100],1:4] # 4th, 7th, 10th and 100th row
# Out:
#        Model  Sales_in_thousands  four_year_resale_value
# 4         A4              20.397                  22.255
# 7       323i              19.747                     NaN
# 10   Century              91.561                  12.475
# 100  M-Class              28.976                     NaN

# %%
sale.iloc[[4,7,10,100],[1,8,9,10,11]]
# Out:
#        Model  Wheelbase  Width  Length  Curb_weight
# 4         A4      102.6   68.2   178.0        2.998
# 7       323i      107.3   68.4   176.0        3.179
# 10   Century      109.0   72.7   194.6        3.368
# 100  M-Class      111.0   72.2   180.6        4.387

# %%
sale.loc[4, "Sales_in_thousands"]
# Out:
# 20.397

# %%
sale.loc[4, ["Sales_in_thousands", "Price_in_thousands"]]
# Out:
# Sales_in_thousands    20.397
# Price_in_thousands     23.99
# Name: 4, dtype: object

# %%
sale.loc[4:8, ["Sales_in_thousands", "Price_in_thousands"]]
# Out:
#    Sales_in_thousands  Price_in_thousands
# 4              20.397               23.99
# 5              18.780               33.95
# 6               1.380               62.00
# 7              19.747               26.99
# 8               9.231               33.40

# %%
sale.loc[4:8, "Model":"Vehicle_type"]
# Out:
#   Model  Sales_in_thousands  four_year_resale_value Vehicle_type
# 4    A4              20.397                  22.255    Passenger
# 5    A6              18.780                  23.555    Passenger
# 6    A8               1.380                  39.000    Passenger
# 7  323i              19.747                     NaN    Passenger
# 8  328i               9.231                  28.675    Passenger

# %%
# subsetting based on conditions

# %%
# Q1. get data for those vehicle which has a price on 10K or less

# %%
# data[(condition1) or/and (condition2) or/and (condition3).....]

# %%
sale[sale["Price_in_thousands"]<=10]
# Out:
#    Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet   Metro              21.855                    5.16
# 62      Hyundai  Accent              41.184                    5.86
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
# 62    Passenger               9.699          1.5        92.0       96.1
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 26   62.6   149.4        1.895           10.3             45.0     4/13/2012
# 62   65.7   166.7        2.240           11.9             31.0     9/10/2012
#
#     Power_perf_factor
# 26          23.276272
# 62          36.672284

# %%
# Q2. get data for those vehicle which has a horse power of 100

# %%
# sale["Horsepower"]==100

# %%
sale[sale["Horsepower"]==100]
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 129       Saturn    SL              80.620                    9.20
# 130       Saturn    SC              24.546                   10.59
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 129    Passenger              10.685          1.9       100.0      102.4
# 130    Passenger              12.535          1.9       100.0      102.4
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 129   66.4   176.9        2.332           12.1             33.0     8/16/2012
# 130   66.4   180.0        2.367           12.1             33.0     3/16/2011
#
#      Power_perf_factor
# 129          39.986425
# 130          40.700072

# %%
# Q3 please get the data for car only

# %%
sale["Vehicle_type"].unique() # Unique values in the column
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %%
sale["Manufacturer"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
sale[sale["Vehicle_type"]=="Car"]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 18      Cadillac        Escalade              14.785                     NaN
# 33      Chrysler  Town & Country              53.480                  19.540
# 40         Dodge      Ram Pickup             227.061                  15.060
# 41         Dodge       Ram Wagon              16.767                  15.510
# 42         Dodge         Ram Van              31.038                  13.425
# 43         Dodge          Dakota             111.313                  11.260
# 44         Dodge         Durango             101.323                     NaN
# 45         Dodge         Caravan             181.749                  12.025
# 52          Ford        Explorer             276.747                  16.640
# 53          Ford        Windstar             155.787                  13.175
# 54          Ford      Expedition             125.338                  23.575
# ...

# %%
# Q4 how many vehicles are there which are sold with price of 40 or more for passenger

# %%
sale[(sale["Price_in_thousands"]>=40) & (sale["Vehicle_type"]=="Passenger")].shape[0]
# Out:
# 20

# %%
# Q5 list me the vehicle which are sold more than 60k and the price is less than 20 k and 
# the manufacture is Toyota also save this data into csv file into local Machine

# %%
my_data=sale[(sale["Sales_in_thousands"]>60)&(sale["Price_in_thousands"]<20)&(sale["Manufacturer"]=="Toyota")]

# %%
my_data
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 136       Toyota  Corolla             142.535                  10.025
# 137       Toyota    Camry             247.994                  13.245
# 140       Toyota   Tacoma              84.087                   9.575
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 136    Passenger              13.108          1.8       120.0       97.0
# 137    Passenger              17.518          2.2       133.0      105.2
# 140          Car              11.528          2.4       142.0      103.3
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 136   66.7   174.0        2.420           13.2             33.0     4/11/2011
# 137   70.1   188.5        2.998           18.5             27.0     2/10/2011
# 140   66.5   178.7        2.580           15.1             23.0      8/1/2011
#
#      Power_perf_factor
# 136          47.968972
# 137          54.372420
# ...

# %%
my_data.to_csv(r"C:\Users\HP\Desktop\DS\PGA44\EDA\abc.csv") # saving it into local machine
# data.to_csv(r"path/data_name.csv")

# %% [markdown]
# #### Column creation and deleteion

# %%
sale["Car_area"]=sale["Length"]*sale["Width"]

# %%
sale.head(2)
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger                21.5          1.8       140.0      101.2   67.3
# 1    Passenger                28.4          3.2       225.0      108.1   70.3
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0   172.4        2.639           13.2             28.0      2/2/2012
# 1   192.9        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor  Car_area
# 0          58.280150  11602.52
# 1          91.370778  13560.87

# %%
# 2.4*1000

# %%
sale["Price"]=sale["Price_in_thousands"]*1000

# %%
sale.head(3)
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger                21.5          1.8       140.0      101.2   67.3
# 1    Passenger                28.4          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0   172.4        2.639           13.2             28.0      2/2/2012
# 1   192.9        3.517           17.2             25.0      6/3/2011
# 2   192.0        3.470           17.2             26.0      1/4/2012
#
#    Power_perf_factor  Car_area    Price
# 0          58.280150  11602.52  21500.0
# ...

# %%
# Copying the j data into global_store
global_store=j.copy()

# %%
# global_store.head(2)

# %%
global_store["Profit_per_quantity"]=global_store["Profit"]/ global_store["Quantity"]

# %%
global_store.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298  CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341   IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
#
#    Customer Name    Segment           City            State  ...    Category  \
# 0    Rick Hansen   Consumer  New York City         New York  ...  Technology
# 1  Justin Ritter  Corporate     Wollongong  New South Wales  ...   Furniture
#
#    Sub-Category                                       Product Name     Sales  \
# 0   Accessories  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650
# 1        Chairs          Novimex Executive Leather Armchair, Black  3709.395
#
#   Quantity Discount    Profit Shipping Cost  Order Priority  \
# 0        7      0.0  762.1845        933.57        Critical
# 1        9      0.1 -288.7650        923.63        Critical
#
#    Profit_per_quantity
# 0             108.8835
# 1             -32.0850
#
# ...

# %%
# Q Create a columns price category , if price is more than 60 k ,
# make is Expensive car else normal car

# %%
sale["Price_Category"]=np.where(sale["Price_in_thousands"]>60, "Expensive","Normal")

# %%
sale.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  four_year_resale_value  \
# 0         Acura      Integra              16.919                  16.360
# 1         Acura           TL              39.384                  19.875
# 2         Acura           CL              14.114                  18.225
# 3         Acura           RL               8.588                  29.725
# 4          Audi           A4              20.397                  22.255
# 5          Audi           A6              18.780                  23.555
# 6          Audi           A8               1.380                  39.000
# 7           BMW         323i              19.747                     NaN
# 8           BMW         328i               9.231                  28.675
# 9           BMW         528i              17.527                  36.125
# 10        Buick      Century              91.561                  12.475
# 11        Buick        Regal              39.350                  13.740
# ...

# %%
def my_cat(x):
    if x>60:
        return "Expensive"
    elif x>40 and x<=60:
        return "Less expensive"
    elif x>20 and x<=40:
        return "Normal"
    else:
        return "Affordable"

# %%
sale["Price_Category_2"]=sale["Price_in_thousands"].apply(my_cat)

# %%
sale["Price_Category_2"].unique()
# Out:
# array(['Normal', 'Affordable', 'Less expensive', 'Expensive'],
#       dtype=object)

# %%
sale["Price_Category_2"].value_counts() # it gives the count of each category in data
# Out:
# Price_Category_2
# Normal            76
# Affordable        57
# Less expensive    16
# Expensive          8
# Name: count, dtype: int64

# %% [markdown]
# #### column deletion

# %%
sale.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor', 'Car_area',
#        'Price', 'Price_Category', 'Price_Category_2'],
#       dtype='object')

# %%
sale1=sale.drop(columns=["Car_area", "Price_Category"])  # deleting the column and saving into sale1

# %%
sale1.head(1)
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                   16.36
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger                21.5          1.8       140.0      101.2   67.3
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0   172.4        2.639           13.2             28.0      2/2/2012
#
#    Power_perf_factor    Price Price_Category_2
# 0           58.28015  21500.0           Normal

# %%
sale1=sale.drop(["Car_area", "Price_Category"], axis=1)   # axis=1 -column, axis=0- row

# %% [markdown]
# #### Sorting of the columns

# %%
sale.sort_values(by=["Sales_in_thousands"])  # by default in ascending order
# Out:
#     Manufacturer          Model  Sales_in_thousands  four_year_resale_value  \
# 83    Mitsubishi         3000GT               0.110                  20.940
# 39         Dodge          Viper               0.916                  58.470
# 99    Mercedes-B          CL500               0.954                     NaN
# 108   Oldsmobile        Cutlass               1.112                  11.240
# 125      Porsche  Carrera Coupe               1.280                  60.625
# ..           ...            ...                 ...                     ...
# 58         Honda         Accord             230.902                  13.210
# 49          Ford         Taurus             245.815                  10.055
# 137       Toyota          Camry             247.994                  13.245
# 52          Ford       Explorer             276.747                  16.640
# 56          Ford       F-Series             540.561                  15.075
#
# ...

# %%
sale2=sale.sort_values(by=["Sales_in_thousands"], ascending=False)  # sorting in Descending order

# %%
sale2.sort_values(by=["Price_in_thousands"], ascending=False, inplace=True) 
# inplace=True , do the action and save the data into the same data name

# %%
sale2.head(2)
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 99   Mercedes-B     CL500               0.954                     NaN
# 95   Mercedes-B  SL-Class               3.311                    58.6
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 99    Passenger                85.5          5.0       302.0      113.6
# 95    Passenger                82.6          5.0       302.0       99.0
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 99   73.1   196.6        4.115           23.2             20.0     4/11/2011
# 95   71.3   177.1        4.125           21.1             20.0     3/17/2011
#
#     Power_perf_factor  Car_area    Price Price_Category Price_Category_2
# 99         141.100985  14371.46  85500.0      Expensive        Expensive
# 95         139.982294  12627.23  82600.0      Expensive        Expensive

# %%
sale2.drop(columns=["Power_perf_factor"], inplace=True)

# %%
sale2.head(2)
# Out:
#    Manufacturer     Model  Sales_in_thousands  four_year_resale_value  \
# 99   Mercedes-B     CL500               0.954                     NaN
# 95   Mercedes-B  SL-Class               3.311                    58.6
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 99    Passenger                85.5          5.0       302.0      113.6
# 95    Passenger                82.6          5.0       302.0       99.0
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 99   73.1   196.6        4.115           23.2             20.0     4/11/2011
# 95   71.3   177.1        4.125           21.1             20.0     3/17/2011
#
#     Car_area    Price Price_Category Price_Category_2
# 99  14371.46  85500.0      Expensive        Expensive
# 95  12627.23  82600.0      Expensive        Expensive

# %% [markdown]
# #### rename the columns

# %%
# Chaning the name of columns
# data.rename(columns={"Old_name":"New_name", "Olde_name":"sdf"})

# %%
sale2.rename(columns={ "four_year_resale_value":"Resale_vale"}, inplace=True)

# %%
sale2.head(2)
# Out:
#    Manufacturer     Model  Sales_in_thousands  Resale_vale Vehicle_type  \
# 99   Mercedes-B     CL500               0.954          NaN    Passenger
# 95   Mercedes-B  SL-Class               3.311         58.6    Passenger
#
#     Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 99                85.5          5.0       302.0      113.6   73.1   196.6
# 95                82.6          5.0       302.0       99.0   71.3   177.1
#
#     Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  Car_area  \
# 99        4.115           23.2             20.0     4/11/2011  14371.46
# 95        4.125           21.1             20.0     3/17/2011  12627.23
#
#       Price Price_Category Price_Category_2
# 99  85500.0      Expensive        Expensive
# 95  82600.0      Expensive        Expensive

# %%
sale3=sale.rename(columns={"Manufacturer":"Maker"})
sale3
# Out:
#      Maker    Model  Sales_in_thousands  four_year_resale_value Vehicle_type  \
# 0    Acura  Integra              16.919                  16.360    Passenger
# 1    Acura       TL              39.384                  19.875    Passenger
# 2    Acura       CL              14.114                  18.225    Passenger
# 3    Acura       RL               8.588                  29.725    Passenger
# 4     Audi       A4              20.397                  22.255    Passenger
# ..     ...      ...                 ...                     ...          ...
# 152  Volvo      V40               3.545                     NaN    Passenger
# 153  Volvo      S70              15.245                     NaN    Passenger
# 154  Volvo      V70              17.531                     NaN    Passenger
# 155  Volvo      C70               3.493                     NaN    Passenger
# 156  Volvo      S80              18.969                     NaN    Passenger
#
# ...

# %%
d=pd.DataFrame({"ID":[101, 102, 103, 104, 101, 104, 107,109],
             "Name":["Sibbu","Harry","John", "Maria", "Sibbu", "John", "Hermoine", "Nebal"],
            "Address":["Delhi", "Noida", "Noida", "Gurugram", "Delhi", "Kolkata", "Vijaynagar",
                       "Ghaziabad"]})
d
# Out:
#     ID      Name     Address
# 0  101     Sibbu       Delhi
# 1  102     Harry       Noida
# 2  103      John       Noida
# 3  104     Maria    Gurugram
# 4  101     Sibbu       Delhi
# 5  104      John     Kolkata
# 6  107  Hermoine  Vijaynagar
# 7  109     Nebal   Ghaziabad

# %%
d.duplicated().sum() # checking duplicated in entire row
# Out:
# 1

# %%
d["ID"].duplicated().sum()
# Out:
# 2

# %%
d1=d.drop_duplicates(keep="first")  # deleted the entire row as it was duplicated 
# d1

# %%
d2=d.drop_duplicates(subset=["ID"], keep="last")
d2
# Out:
#     ID      Name     Address
# 1  102     Harry       Noida
# 2  103      John       Noida
# 4  101     Sibbu       Delhi
# 5  104      John     Kolkata
# 6  107  Hermoine  Vijaynagar
# 7  109     Nebal   Ghaziabad

# %%
j.duplicated().sum()
# Out:
# 0

# %%
j.shape
# Out:
# (51290, 24)

# %%
j1=j.drop_duplicates(subset=["Order ID"])
j1.shape
# Out:
# (25035, 24)

# %%
# j1["Order ID"].value_counts()

# %%
# j["Order ID"].value_counts()

# %% [markdown]
# #### Missing Value

# %%
sale.isnull().sum()  # gives the missing count in each columns
# Out:
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb_weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# Latest_Launch              0
# Power_perf_factor          2
# Car_area                   1
# Price                      2
# Price_Category             0
# Price_Category_2           0
# dtype: int64

# %%
sale.shape
# Out:
# (157, 20)

# %%
# Treatment : deletion
s1=sale.dropna()  # Droping all those rows wherever we have missing

# %%
s1.shape
# Out:
# (117, 20)

# %%
# Treatment : imputation

# %%
H=pd.DataFrame({"Pat_id":[101, 104, 108,110, 101],
               "Dr":["Vishwas", "Gupta", "Gupta", "Khan", "Vishwas"],
               "Disease":["Fever", "Brain issue", "Neuro", "Bone", "Cold"]})
H
# Out:
#    Pat_id       Dr      Disease
# 0     101  Vishwas        Fever
# 1     104    Gupta  Brain issue
# 2     108    Gupta        Neuro
# 3     110     Khan         Bone
# 4     101  Vishwas         Cold

# %%
# inner join - common records from both tables
# Left join - all records from left and matching records from right table
# right join - all records from right table and matching records from left
# outer join - all records from both table

# %%
# pd.merge(left_table, right_table, on="common_column", how="inner/left/right/outer")
# pd.merge(left_table, right_table, left_on="column_from_left",
#          right_on="columns_from_right"
#          how="inner/left/right/outer")

# %%
# d.head(2)

# %%
# H.head(1)

# %%
# people who have visited to hospital from my data base - common - inner
inner_join_dh=pd.merge(d, H,left_on=["ID"], right_on=["Pat_id"],how="inner")
# inner_join_dh.drop_duplicates()

# %%
g1=pd.merge(d, H,left_on=["ID"], right_on=["Pat_id"],how="left")

# %%
g1
# Out:
#     ID      Name     Address  Pat_id       Dr      Disease
# 0  101     Sibbu       Delhi   101.0  Vishwas        Fever
# 1  101     Sibbu       Delhi   101.0  Vishwas         Cold
# 2  102     Harry       Noida     NaN      NaN          NaN
# 3  103      John       Noida     NaN      NaN          NaN
# 4  104     Maria    Gurugram   104.0    Gupta  Brain issue
# 5  101     Sibbu       Delhi   101.0  Vishwas        Fever
# 6  101     Sibbu       Delhi   101.0  Vishwas         Cold
# 7  104      John     Kolkata   104.0    Gupta  Brain issue
# 8  107  Hermoine  Vijaynagar     NaN      NaN          NaN
# 9  109     Nebal   Ghaziabad     NaN      NaN          NaN

# %%
r1=pd.merge(d, H,left_on=["ID"], right_on=["Pat_id"],how="right")
r1
# Out:
#       ID   Name   Address  Pat_id       Dr      Disease
# 0  101.0  Sibbu     Delhi     101  Vishwas        Fever
# 1  101.0  Sibbu     Delhi     101  Vishwas        Fever
# 2  104.0  Maria  Gurugram     104    Gupta  Brain issue
# 3  104.0   John   Kolkata     104    Gupta  Brain issue
# 4    NaN    NaN       NaN     108    Gupta        Neuro
# 5    NaN    NaN       NaN     110     Khan         Bone
# 6  101.0  Sibbu     Delhi     101  Vishwas         Cold
# 7  101.0  Sibbu     Delhi     101  Vishwas         Cold

# %%
pd.merge(d, H,left_on=["ID"], right_on=["Pat_id"],how="outer")
# Out:
#        ID      Name     Address  Pat_id       Dr      Disease
# 0   101.0     Sibbu       Delhi   101.0  Vishwas        Fever
# 1   101.0     Sibbu       Delhi   101.0  Vishwas         Cold
# 2   101.0     Sibbu       Delhi   101.0  Vishwas        Fever
# 3   101.0     Sibbu       Delhi   101.0  Vishwas         Cold
# 4   102.0     Harry       Noida     NaN      NaN          NaN
# 5   103.0      John       Noida     NaN      NaN          NaN
# 6   104.0     Maria    Gurugram   104.0    Gupta  Brain issue
# 7   104.0      John     Kolkata   104.0    Gupta  Brain issue
# 8   107.0  Hermoine  Vijaynagar     NaN      NaN          NaN
# 9   109.0     Nebal   Ghaziabad     NaN      NaN          NaN
# 10    NaN       NaN         NaN   108.0    Gupta        Neuro
# 11    NaN       NaN         NaN   110.0     Khan         Bone

# %%
r2=r1[r1["ID"].isna()]   # Those who exist in hospital but not in d Database
r2
# Out:
#    ID Name Address  Pat_id     Dr Disease
# 4 NaN  NaN     NaN     108  Gupta   Neuro
# 5 NaN  NaN     NaN     110   Khan    Bone

# %%
g2=g1[g1["Pat_id"].isna()]
g2
# Out:
#     ID      Name     Address  Pat_id   Dr Disease
# 2  102     Harry       Noida     NaN  NaN     NaN
# 3  103      John       Noida     NaN  NaN     NaN
# 8  107  Hermoine  Vijaynagar     NaN  NaN     NaN
# 9  109     Nebal   Ghaziabad     NaN  NaN     NaN

# %%
pd.concat([r2, g2], axis=0)  # appending / concat
# Out:
#       ID      Name     Address  Pat_id     Dr Disease
# 4    NaN       NaN         NaN   108.0  Gupta   Neuro
# 5    NaN       NaN         NaN   110.0   Khan    Bone
# 2  102.0     Harry       Noida     NaN    NaN     NaN
# 3  103.0      John       Noida     NaN    NaN     NaN
# 8  107.0  Hermoine  Vijaynagar     NaN    NaN     NaN
# 9  109.0     Nebal   Ghaziabad     NaN    NaN     NaN

# %% [markdown]
# ### Basic Statistics

# %%
# min, max, mean-average, median, mode, var, std, skew, kurt , percentile, decile etc..

# %%
# Average Sales 
sale["Sales_in_thousands"].mean()
# Out:
# 52.99807643312102

# %%
# which car has the highest horse power
sale["Horsepower"].max()
# Out:
# 450.0

# %%
sale[sale["Horsepower"]==450]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 39        Dodge  Viper               0.916                   58.47
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 39    Passenger              69.725          8.0       450.0       96.2
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 39   75.7   176.7        3.375           19.0             16.0      8/7/2011
#
#     Power_perf_factor  Car_area    Price Price_Category Price_Category_2
# 39         188.144323  13376.19  69725.0      Expensive        Expensive

# %%
# cheapest Vehicle
sale["Price_in_thousands"].min()
# Out:
# 9.235

# %%
sale[sale["Price_in_thousands"]==9.235]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 26   62.6   149.4        1.895           10.3             45.0     4/13/2012
#
#     Power_perf_factor  Car_area   Price Price_Category Price_Category_2
# 26          23.276272   9352.44  9235.0         Normal       Affordable

# %%
sale["Price_in_thousands"].median()
# Out:
# 22.799

# %%
# 3,4,6,9,11,56,67

# %%
sale["Manufacturer"].mode()  # a term which has highest freq
# Out:
# 0    Dodge
# 1     Ford
# Name: Manufacturer, dtype: object

# %%
# sale["Manufacturer"].value_counts()

# %%
sale["Sales_in_thousands"].var()  # Variance
# Out:
# 4628.002257314634

# %%
sale["Sales_in_thousands"].std() # Standard Deviation
# Out:
# 68.02942199750512

# %%
sale["Sales_in_thousands"].skew() # Skewness
# Out:
# 3.408518366470572

# %%
sale["Sales_in_thousands"].kurt()  # Kurtosis
# Out:
# 17.55734423299965

# %%
sale["Sales_in_thousands"].quantile(.10)  # 10th Percetile
# Out:
# 5.453600000000001

# %%
sale["Price_in_thousands"].quantile(.95)
# Out:
# 55.834999999999894

# %%
sale[["Price_in_thousands", "Sales_in_thousands"]].mean()
# Out:
# Price_in_thousands    27.390755
# Sales_in_thousands    52.998076
# dtype: float64

# %%
# sd=sale[sale["Manufacturer"].isin(["Audi", "Volvo"])]

# %%
sale.describe()  # 5 pointer summary 
# Highest value in the dataset.
# Third quartile (Q3)—greater than 75% of the values in the dataset
# Median or second quartile (Q2)—splits the dataset in half.
# First quartile (Q1)—greater than 25% of the values.
# Lowest value in the dataset.
# Out:
#        Sales_in_thousands  four_year_resale_value  Price_in_thousands  \
# count          157.000000              121.000000          155.000000
# mean            52.998076               18.072975           27.390755
# std             68.029422               11.453384           14.351653
# min              0.110000                5.160000            9.235000
# 25%             14.114000               11.260000           18.017500
# 50%             29.450000               14.180000           22.799000
# 75%             67.956000               19.875000           31.947500
# max            540.561000               67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# ...

# %%
# Group by summary
sale.groupby('Vehicle_type')["Price_in_thousands"].mean()
# Out:
# Vehicle_type
# Car          26.319975
# Passenger    27.763200
# Name: Price_in_thousands, dtype: float64

# %%
# sale.groupby('Manufacturer')["Sales_in_thousands"].sum()
# sale.groupby('Manufacturer')["Sales_in_thousands"].min()
# sale.groupby('Manufacturer')["Sales_in_thousands"].max()
sale.groupby('Manufacturer')["Sales_in_thousands"].mean()
# Out:
# Manufacturer
# Acura          19.751250
# Audi           13.519000
# BMW            15.501667
# Buick          60.504750
# Cadillac       22.435600
# Chevrolet      61.596111
# Chrysler       28.817286
# Dodge          82.740818
# Ford          183.875909
# Honda         118.534800
# Hyundai        45.775333
# Infiniti       23.713000
# Jaguar         15.467000
# Jeep           97.717667
# Lexus          17.807167
# Lincoln        28.544667
# Mercedes-B     13.013889
# Mercury        39.666500
# Mitsubishi     25.842143
# Nissan         57.090714
# Oldsmobile     29.831500
# Plymouth       16.000250
# Pontiac        61.755667
# Porsche         4.042667
# Saab           10.653000
# Saturn         33.770000
# Subaru         40.067500
# Toyota         82.245000
# Volkswagen     34.868667
# Volvo          12.623333
# Name: Sales_in_thousands, dtype: float64

# %%
sale.groupby(["Manufacturer"]).agg({"Price_in_thousands":["min", "max", "mean", "count"],
                                   "Sales_in_thousands":["min", "max"]})
# Out:
#              Price_in_thousands                          Sales_in_thousands  \
#                             min     max       mean count                min
# Manufacturer
# Acura                    21.500  42.000  30.633333     3              8.588
# Audi                     23.990  62.000  39.980000     3              1.380
# BMW                      26.990  38.900  33.096667     3              9.231
# Buick                    21.975  31.965  26.781250     4             27.851
# Cadillac                 31.010  46.225  40.254000     5              6.536
# Chevrolet                 9.235  45.705  20.022778     9             17.947
# Chrysler                 16.480  29.185  23.430833     6              7.854
# Dodge                    12.640  69.725  24.213636    11              0.916
# Ford                     12.050  36.135  21.047273    11             35.068
# Honda                    12.885  26.600  20.277000     5             12.855
# ...

# %%
sale.groupby(["Manufacturer", "Vehicle_type"]).agg({"Price_in_thousands":["min", "max", 
                                                                          "mean", "count"],
                                                    
                                   "Sales_in_thousands":["min", "max"]})
# Out:
#                           Price_in_thousands                           \
#                                          min     max       mean count
# Manufacturer Vehicle_type
# Acura        Passenger                21.500  42.000  30.633333     3
# Audi         Passenger                23.990  62.000  39.980000     3
# BMW          Passenger                26.990  38.900  33.096667     3
# Buick        Passenger                21.975  31.965  26.781250     4
# Cadillac     Car                      46.225  46.225  46.225000     1
#              Passenger                31.010  44.475  38.761250     4
# Chevrolet    Passenger                 9.235  45.705  20.022778     9
# Chrysler     Car                         NaN     NaN        NaN     0
#              Passenger                16.480  29.185  23.430833     6
# Dodge        Car                      16.980  26.310  20.367500     6
#              Passenger                12.640  69.725  28.829000     5
# ...

# %% [markdown]
# #### graphs

# %%
# Bar Plot
sale["Vehicle_type"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Vehicle_type'>

# %%
sale["Vehicle_type"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
# sale[["Sales_in_thousands", "four_year_resale_value"]]
sale.plot.scatter(x="Sales_in_thousands", y="four_year_resale_value", s=100) # s= bubble size
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='four_year_resale_value'>
