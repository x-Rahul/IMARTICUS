# %% [markdown]
# # Plots

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
x1=[1, 2, 5, 8, 10, 23]
x2 = list(map(lambda x:x**2, x1))
x3 = [3, 8, 10, 15, 14, 20]
x4 = [8, 12, 14, 18, 20, 23]

# %% [markdown]
# ## Line Chart

# %%
# plt.plot(arg1, arg2, .....)
# plt.title("A vs B")
# plt.xlabel
# plt.ylabel
# plt.show()

# %%
plt.plot(x1, x2)

# %%
plt.figure(figsize=(6,3))
plt.plot(x1, x2)
plt.title("Line Chart")
plt.xlabel("x1 data")
plt.ylabel("x2 data (sq of x)")
# Out:
# Text(0, 0.5, 'x2 data (sq of x)')

# %%
plt.figure(figsize=(6,3))
plt.plot(x1, x2, 
         color='c', 
         linestyle='-.', 
         linewidth = 2, 
         marker='p', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)
plt.title("Line Chart")
plt.xlabel("x1 data")
plt.ylabel("x2 data (sq of x1)")
plt.xlim(0, 30)
plt.xticks(color='g')
# plt.xticks([0, 10, 30], ["A", "B", "C"])
plt.tick_params(labelsize=12, color = 'r')

# %%
plt.figure(figsize=(6,3))
plt.plot(x1, x2, 
         color='c', 
         linestyle='-.', 
         linewidth = 2, 
         marker='p', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)
plt.plot(x3, x4, 
         color='r', 
         linestyle='-.', 
         linewidth = 2,
         marker='*', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)
plt.title("Line Chart")
plt.xlabel("x1 data")
plt.ylabel("x2 data (sq of x1)")
plt.xlim(0, 30)
plt.xticks(color='g')
# plt.xticks([0, 10, 30], ["A", "B", "C"])
plt.tick_params(labelsize=12, color = 'r')

# %%
theta = np.linspace(-2*np.pi, 2*np.pi, 2560, endpoint=True)
s = np.sin(theta)
c = np.cos(theta)
plt.plot(s, color='g')
plt.plot(c, color='r')

# %% [markdown]
# ### subplots

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(x1, x2, 
         color='c', 
         linestyle='-.', 
         linewidth = 2, 
         marker='p', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)
plt.subplot(1,2,2)
plt.plot(x3, x4, 
         color='r', 
         linestyle='-.', 
         linewidth = 2, 
         marker='*', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)

# %%
plt.figure(figsize=(5,10))
plt.subplot(2,1,1)
plt.plot(x1, x2, 
         color='c', 
         linestyle='-.', 
         linewidth = 2, 
         marker='p', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)
plt.subplot(2,1,2)
plt.plot(x3, x4, 
         color='r', 
         linestyle='-.', 
         linewidth = 2, 
         marker='*', 
         markersize=8,
         markerfacecolor = 'b',
         markeredgecolor = 'k'
)

# %% [markdown]
# ## Bar chart

# %%
superstore = pd.read_excel(r"/Users/rahulmeena/Imarticus/GitHub/IMARTICUS/Datasets/class_exercise/Global Superstore.xls")

# %%
superstore.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
d = pd.DataFrame(superstore['Segment'].value_counts()).reset_index()
d
# Out:
#        Segment  count
# 0     Consumer  26518
# 1    Corporate  15429
# 2  Home Office   9343

# %%
plt.bar(x=d["Segment"], height=d["count"], color=['r', 'g', 'b'])
# Out:
# <BarContainer object of 3 artists>

# %%
sns.barplot(x=d["Segment"], y=d["count"])
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %%
plt.pie(x=d["count"],labels= d["Segment"], colors=['r','g','b'])
plt.show()

# %%
plt.pie(x=d["count"],labels= d["Segment"], 
        colors=['r','g','c'],
        shadow="True",
        explode=[0,0,.2],
        autopct="%.2f%%",
        textprops={"fontsize": 12, "color": "navy"},
        wedgeprops={"linewidth": 3, "edgecolor":"black"},
        pctdistance=.5
        
)
plt.show()

# %% [markdown]
# ## Hitogram

# %%
plt.hist(superstore["Sales"], 40)
plt.show()

# %%
car_sales =  pd.read_csv(r"/Users/rahulmeena/Imarticus/GitHub/IMARTICUS/Datasets/class_exercise/Car_sales.csv")

# %%
car_sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sns.histplot(data=car_sales)
plt.show()

# %%
sns.histplot(data=car_sales, x='Sales_in_thousands', 
             hue='Vehicle_type',
             multiple="dodge"
)
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='Count'>

# %%
plt.figure(figsize=(9,4))
sns.displot(data=car_sales, x="Sales_in_thousands",
            hue="Vehicle_type",
            kind="kde")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(9,4))
sns.displot(data=car_sales, x="Sales_in_thousands",
            hue="Vehicle_type",
            multiple="stack",
            kind="kde")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0          Acura  Integra              16.919                  16.360
# 1          Acura       TL              39.384                  19.875
# 2          Acura       CL              14.114                  18.225
# 3          Acura       RL               8.588                  29.725
# 4           Audi       A4              20.397                  22.255
# ..           ...      ...                 ...                     ...
# 152        Volvo      V40               3.545                     NaN
# 153        Volvo      S70              15.245                     NaN
# 154        Volvo      V70              17.531                     NaN
# 155        Volvo      C70               3.493                     NaN
# 156        Volvo      S80              18.969                     NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
sns.jointplot(data=car_sales, x="Sales_in_thousands", y="Price_in_thousands",
            hue="Vehicle_type",
            kind="kde")
plt.show()

# %% [markdown]
# ## Pair plot

# %%
car_sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sns.pairplot(car_sales)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=car_sales,
            x = 'Vehicle_type',
            y = 'Price_in_thousands',
            kind = 'swarm'
           )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
superstore.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
superstore_sample = superstore.sample(5000)

# %%
sns.catplot(
    data=superstore_sample,
    x='Segment',
    y='Discount',
    kind = 'swarm'
)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 88.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 83.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 76.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %% [markdown]
# ## Box Plot

# %%
# # plt.figure(figsize=(7,12))
sns.boxplot(
    data=car_sales,
    x='Vehicle_type',
    y='Sales_in_thousands'
)
# Out:
# <Axes: xlabel='Vehicle_type', ylabel='Sales_in_thousands'>

# %%
plt.boxplot()

# %%
sns.regplot(data= car_sales,
                x='Price_in_thousands',
                y='Sales_in_thousands'
)
# Out:
# <Axes: xlabel='Price_in_thousands', ylabel='Sales_in_thousands'>

# %%
sns.violinplot(
    data=car_sales,
    x='Vehicle_type',
    y='Sales_in_thousands'
)
# Out:
# <Axes: xlabel='Vehicle_type', ylabel='Sales_in_thousands'>
