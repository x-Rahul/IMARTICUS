# %%
import pandas as pd
import numpy as np
import os

# %%
arr = pd.Series([4,3,5,6])
arr
# Out:
# 0    4
# 1    3
# 2    5
# 3    6
# dtype: int64

# %%
arr.values
# Out:
# array([4, 3, 5, 6])

# %%
arr.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
arr[1]
# Out:
# 3

# %%
arr[1:3]
# Out:
# 1    3
# 2    5
# dtype: int64

# %%
arr2 = pd.Series([0.25, 0.54, 0.76, 0.50], index=['a', 'b', 'c', 'd'])
arr2
# Out:
# a    0.25
# b    0.54
# c    0.76
# d    0.50
# dtype: float64

# %%
arr2['c']
# Out:
# 0.76

# %%
arr2['a':'c']
# Out:
# a    0.25
# b    0.54
# c    0.76
# dtype: float64

# %%
dic = {
    '2': 'a',
    '1': 'b',
    '3': 'd'
}
series = pd.Series(dic)
series
# Out:
# 2    a
# 1    b
# 3    d
# dtype: object

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': 149995}
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({
    'population': population,
    'area': area
})
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
print(states.index)
print(states.columns)
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')
# Index(['population', 'area'], dtype='object')

# %%
states.values[1]
# Out:
# array([26448193,   695662])

# %%
states['area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
states.T
# Out:
#             California     Texas  New York   Florida  Illinois
# population    38332521  26448193  19651127  19552860  12882135
# area            423967    695662    141297    170312    149995

# %%
print(population.keys())
print(population.values)
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')
# [38332521 26448193 19651127 19552860 12882135]

# %%
list(population.items())
# Out:
# [('California', 38332521),
#  ('Texas', 26448193),
#  ('New York', 19651127),
#  ('Florida', 19552860),
#  ('Illinois', 12882135)]

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
pd.DataFrame(
    np.random.rand(3,2), index=['a', 'b', 'c'], columns=['foo', 'bar']
)
# Out:
#         foo       bar
# a  0.353363  0.969206
# b  0.493099  0.520618
# c  0.410776  0.592490

# %%
sales =  pd.read_csv(r"/Users/rahulmeena/Imarticus/GitHub/IMARTICUS/Datasets/class_exercise/Car_sales.csv")

# %%
superstore = pd.read_excel(r"/Users/rahulmeena/Imarticus/GitHub/IMARTICUS/Datasets/class_exercise/Global Superstore.xls")

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales.shape
# Out:
# (157, 16)

# %%
sales.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
sales.dtypes
# Out:
# Manufacturer               object
# Model                      object
# Sales_in_thousands        float64
# four_year_resale_value    float64
# Vehicle_type               object
# Price_in_thousands        float64
# Engine_size               float64
# Horsepower                float64
# Wheelbase                 float64
# Width                     float64
# Length                    float64
# Curb_weight               float64
# Fuel_capacity             float64
# Fuel_efficiency           float64
# Latest_Launch              object
# Power_perf_factor         float64
# dtype: object

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturer            157 non-null    object
#  1   Model                   157 non-null    object
#  2   Sales_in_thousands      157 non-null    float64
#  3   four_year_resale_value  121 non-null    float64
#  4   Vehicle_type            157 non-null    object
#  5   Price_in_thousands      155 non-null    float64
#  6   Engine_size             156 non-null    float64
#  7   Horsepower              156 non-null    float64
#  8   Wheelbase               156 non-null    float64
#  9   Width                   156 non-null    float64
#  10  Length                  156 non-null    float64
#  11  Curb_weight             155 non-null    float64
#  12  Fuel_capacity           156 non-null    float64
#  13  Fuel_efficiency         154 non-null    float64
# ...

# %%
# Subset of Data
# 1. Row subset
# 2. Column subset
# 3. row and column subset
# 4. conditional subsetting
# Sampling
# Creating new columns
# Deleting columns
# Duplicate check and remove
# Missing value identification and treatment
# Sorting (order by - ascending or descending)
# Renamming
# Merging, concate and appending
# Statistics - mean, median, mode, count, std,
# Summary - pivot table, group by

# %% [markdown]
# ### Subset of data

# %%
sales.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', 'four_year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
sales.Price_in_thousands
# Out:
# 0      21.50
# 1      28.40
# 2        NaN
# 3      42.00
# 4      23.99
#        ...
# 152    24.40
# 153    27.50
# 154    28.80
# 155    45.50
# 156    36.00
# Name: Price_in_thousands, Length: 157, dtype: float64

# %%
sales["Price_in_thousands"]
# Out:
# 0      21.50
# 1      28.40
# 2        NaN
# 3      42.00
# 4      23.99
#        ...
# 152    24.40
# 153    27.50
# 154    28.80
# 155    45.50
# 156    36.00
# Name: Price_in_thousands, Length: 157, dtype: float64

# %%
sales[["Manufacturer", "Sales_in_thousands", "Engine_size"]]
# Out:
#     Manufacturer  Sales_in_thousands  Engine_size
# 0          Acura              16.919          1.8
# 1          Acura              39.384          3.2
# 2          Acura              14.114          3.2
# 3          Acura               8.588          3.5
# 4           Audi              20.397          1.8
# ..           ...                 ...          ...
# 152        Volvo               3.545          1.9
# 153        Volvo              15.245          2.4
# 154        Volvo              17.531          2.4
# 155        Volvo               3.493          2.3
# 156        Volvo              18.969          2.9
#
# [157 rows x 3 columns]

# %%
# row and column extract

# %%
# sales.loc[] # it takes label as input
# sales.iloc[] # it takes index as input

# %%
data = pd.Series(['a', 'b', 'c', 'd'], index=[1,3,5,7])
data
# Out:
# 1    a
# 3    b
# 5    c
# 7    d
# dtype: object

# %%
data[1] # Explicit indexing
# Out:
# 'a'

# %%
data[1:3] # Implicit Indexing
# Out:
# 3    b
# 5    c
# dtype: object

# %%
print(data.loc[1])
print(data.iloc[1])
# Out:
# a
# b

# %%
print(data.loc[1:3])
print(data.iloc[1:3])
# Out:
# 1    a
# 3    b
# dtype: object
# 3    b
# 5    c
# dtype: object

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales.iloc[4, 1]
# Out:
# 'A4'

# %%
sales.iloc[3:7, 1:4]
# Out:
#   Model  Sales_in_thousands  four_year_resale_value
# 3    RL               8.588                  29.725
# 4    A4              20.397                  22.255
# 5    A6              18.780                  23.555
# 6    A8               1.380                  39.000

# %%
sales.iloc[[4, 7, 10, 100], [0, 1, 8, 9,10, 11]]
# Out:
#     Manufacturer    Model  Wheelbase  Width  Length  Curb_weight
# 4           Audi       A4      102.6   68.2   178.0        2.998
# 7            BMW     323i      107.3   68.4   176.0        3.179
# 10         Buick  Century      109.0   72.7   194.6        3.368
# 100   Mercedes-B  M-Class      111.0   72.2   180.6        4.387

# %%
sales.loc[4:8, "Model" : "Vehicle_type"]
# Out:
#   Model  Sales_in_thousands  four_year_resale_value Vehicle_type
# 4    A4              20.397                  22.255    Passenger
# 5    A6              18.780                  23.555    Passenger
# 6    A8               1.380                  39.000    Passenger
# 7  323i              19.747                     NaN    Passenger
# 8  328i               9.231                  28.675    Passenger

# %%
# Q1 get data for those vehicle which has a price if 20k or less
sales[sales["Price_in_thousands"] < 10]
# Out:
#    Manufacturer   Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet   Metro              21.855                    5.16
# 62      Hyundai  Accent              41.184                    5.86
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
# 62    Passenger               9.699          1.5        92.0       96.1
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 26   62.6   149.4        1.895           10.3             45.0     4/13/2012
# 62   65.7   166.7        2.240           11.9             31.0     9/10/2012
#
#     Power_perf_factor
# 26          23.276272
# 62          36.672284

# %%
# Q2 Get data for those vehicle which has horse power of 100
sales[sales["Horsepower"] == 100]
# Out:
#     Manufacturer Model  Sales_in_thousands  four_year_resale_value  \
# 129       Saturn    SL              80.620                    9.20
# 130       Saturn    SC              24.546                   10.59
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 129    Passenger              10.685          1.9       100.0      102.4
# 130    Passenger              12.535          1.9       100.0      102.4
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 129   66.4   176.9        2.332           12.1             33.0     8/16/2012
# 130   66.4   180.0        2.367           12.1             33.0     3/16/2011
#
#      Power_perf_factor
# 129          39.986425
# 130          40.700072

# %%
# Q3 Please create the data for car only

# %%
sales[sales["Vehicle_type"] == "Car"]
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 18      Cadillac        Escalade              14.785                     NaN
# 33      Chrysler  Town & Country              53.480                  19.540
# 40         Dodge      Ram Pickup             227.061                  15.060
# 41         Dodge       Ram Wagon              16.767                  15.510
# 42         Dodge         Ram Van              31.038                  13.425
# 43         Dodge          Dakota             111.313                  11.260
# 44         Dodge         Durango             101.323                     NaN
# 45         Dodge         Caravan             181.749                  12.025
# 52          Ford        Explorer             276.747                  16.640
# 53          Ford        Windstar             155.787                  13.175
# 54          Ford      Expedition             125.338                  23.575
# ...

# %%
sales["Vehicle_type"].unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %%
sales["Manufacturer"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
# Q4 How many vehicles are there which are sold with price of 80 or more for passenger
sales[(sales["Price_in_thousands"]>80) & (sales["Vehicle_type"] == 'Passenger')].shape[0]
# Out:
# 2

# %%
# Q5 List me the vehicle which are sold more than 60k and the price is less than 20k and maufacturer is toyota also save this file in local machine
my_sales = sales[
                    (sales["Sales_in_thousands"] > 60) & 
                    (sales["Price_in_thousands"] < 20) & 
                    (sales["Manufacturer"] == "Toyota")
]
my_sales.to_csv("/Users/rahulmeena/Imarticus/GitHub/IMARTICUS/Datasets/class_exercise/test01.csv")

# %%
# Adding new column to the data
sales["Car_area"] = sales["Length"]*sales["Width"]

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
# Q6 Create a columns Price category, if price is more than 60k make it expensive else normal car
# sales["Price_category"] = "Expensive" if sales["Price_in_thousands"] > 60 else "Normal"
sales["Price_category"] = np.where(sales["Price_in_thousands"] > 60, "Expensive", "Normal")

# %%
sales.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  four_year_resale_value  \
# 0         Acura      Integra              16.919                  16.360
# 1         Acura           TL              39.384                  19.875
# 2         Acura           CL              14.114                  18.225
# 3         Acura           RL               8.588                  29.725
# 4          Audi           A4              20.397                  22.255
# 5          Audi           A6              18.780                  23.555
# 6          Audi           A8               1.380                  39.000
# 7           BMW         323i              19.747                     NaN
# 8           BMW         328i               9.231                  28.675
# 9           BMW         528i              17.527                  36.125
# 10        Buick      Century              91.561                  12.475
# 11        Buick        Regal              39.350                  13.740
# ...

# %%
def my_category(x):
    if x>60: return "Expensive"
    elif x>40: return "Less_expensive"
    elif x>20: return "Normal"
    else: return "Affordable"

# %%
sales["Price_category_2"] = sales["Price_in_thousands"].apply(my_category)

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales["Price_category_2"].value_counts()
# Out:
# Price_category_2
# Normal            76
# Affordable        57
# Less_expensive    16
# Expensive          8
# Name: count, dtype: int64

# %%
pd.Series([4,6,5,3])
# Out:
# 0    4
# 1    6
# 2    5
# 3    3
# dtype: int64

# %%
pd.Series(np.array([5,3,2,42,5,4]), index=np.arange(0,12,2))
# Out:
# 0      5
# 2      3
# 4      2
# 6     42
# 8      5
# 10     4
# dtype: int64

# %%
class_dict = {
    'X': ["math", "sci", "eng"],
    'Y': ["math", "sci"],
    'Z': ["sci"]
}

class_Series = pd.Series(class_dict)
class_Series[['Y','Z']]
# Out:
# Y    [math, sci]
# Z          [sci]
# dtype: object

# %%
studentMarks = pd.Series(np.array([55,32,88,45,75]), index=['sophie', 'john', 'jack', 'tim', 'june'])
studentMarks[studentMarks>50]
# Out:
# sophie    55
# jack      88
# june      75
# dtype: int64

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales1 = sales.drop(columns=["Car_area", "Price_category_2", "Price_category"])

# %%
sales1.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales1.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %% [markdown]
# Sorting

# %%
sales1.sort_values(by=['Price_in_thousands'], ascending=False, inplace=True)

# %%
sales1.head()
# Out:
#     Manufacturer           Model  Sales_in_thousands  four_year_resale_value  \
# 99    Mercedes-B           CL500               0.954                     NaN
# 95    Mercedes-B        SL-Class               3.311                  58.600
# 126      Porsche  Carrera Cabrio               1.866                  67.550
# 125      Porsche   Carrera Coupe               1.280                  60.625
# 39         Dodge           Viper               0.916                  58.470
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 99     Passenger              85.500          5.0       302.0      113.6
# 95     Passenger              82.600          5.0       302.0       99.0
# 126    Passenger              74.970          3.4       300.0       92.6
# 125    Passenger              71.020          3.4       300.0       92.6
# 39     Passenger              69.725          8.0       450.0       96.2
#
# ...

# %%
sales2 = sales.sort_values(by=['Price_in_thousands'])

# %%
sales2.head()
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 26     Chevrolet    Metro              21.855                   5.160
# 62       Hyundai   Accent              41.184                   5.860
# 129       Saturn       SL              80.620                   9.200
# 140       Toyota   Tacoma              84.087                   9.575
# 63       Hyundai  Elantra              66.692                   7.825
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26     Passenger               9.235          1.0        55.0       93.1
# 62     Passenger               9.699          1.5        92.0       96.1
# 129    Passenger              10.685          1.9       100.0      102.4
# 140          Car              11.528          2.4       142.0      103.3
# 63     Passenger              11.799          2.0       140.0      100.4
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales2.head()
# Out:
#     Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 26     Chevrolet    Metro              21.855                   5.160
# 62       Hyundai   Accent              41.184                   5.860
# 129       Saturn       SL              80.620                   9.200
# 140       Toyota   Tacoma              84.087                   9.575
# 63       Hyundai  Elantra              66.692                   7.825
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26     Passenger               9.235          1.0        55.0       93.1
# 62     Passenger               9.699          1.5        92.0       96.1
# 129    Passenger              10.685          1.9       100.0      102.4
# 140          Car              11.528          2.4       142.0      103.3
# 63     Passenger              11.799          2.0       140.0      100.4
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
#Rename a column
sales3 = sales2.rename(columns={"Manufacturer":"Maker"})

# %%
sales3.head()
# Out:
#          Maker    Model  Sales_in_thousands  four_year_resale_value  \
# 26   Chevrolet    Metro              21.855                   5.160
# 62     Hyundai   Accent              41.184                   5.860
# 129     Saturn       SL              80.620                   9.200
# 140     Toyota   Tacoma              84.087                   9.575
# 63     Hyundai  Elantra              66.692                   7.825
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26     Passenger               9.235          1.0        55.0       93.1
# 62     Passenger               9.699          1.5        92.0       96.1
# 129    Passenger              10.685          1.9       100.0      102.4
# 140          Car              11.528          2.4       142.0      103.3
# 63     Passenger              11.799          2.0       140.0      100.4
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %% [markdown]
# ## Dataframe

# %%
Data = pd.DataFrame({
    "ID": [101,102,103,104, 101,104,107,209],
    "Name": ["Sibbu", "Harry", "John", "Maria", "Sibbu", "John", "Hermoine", "Nebal"],
    "Address": ["Delhi", "noida", "noida", "Gurugram", "Delhi", "Kolkata", "Vijaynagar", "Gaziabad"]
})

# %%
Data
# Out:
#     ID      Name     Address
# 0  101     Sibbu       Delhi
# 1  102     Harry       noida
# 2  103      John       noida
# 3  104     Maria    Gurugram
# 4  101     Sibbu       Delhi
# 5  104      John     Kolkata
# 6  107  Hermoine  Vijaynagar
# 7  209     Nebal    Gaziabad

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       8 non-null      int64
#  1   Name     8 non-null      object
#  2   Address  8 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 324.0+ bytes

# %%
Data.duplicated().sum()
# Out:
# 1

# %%
Data["ID"].duplicated().sum()
# Out:
# 2

# %%
Data1 = Data.drop_duplicates(keep="first")

# %%
Data1
# Out:
#     ID      Name     Address
# 0  101     Sibbu       Delhi
# 1  102     Harry       noida
# 2  103      John       noida
# 3  104     Maria    Gurugram
# 5  104      John     Kolkata
# 6  107  Hermoine  Vijaynagar
# 7  209     Nebal    Gaziabad

# %%
superstore.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
superstore["Order ID"].value_counts()
# Out:
# Order ID
# CA-2014-100111    14
# NI-2014-8880      13
# TO-2014-9950      13
# IN-2012-41261     13
# IN-2013-42311     13
#                   ..
# ID-2014-68085      1
# ID-2012-85221      1
# CA-2012-119697     1
# CA-2011-151967     1
# MX-2012-134460     1
# Name: count, Length: 25035, dtype: int64

# %%
superstore2 = superstore.drop_duplicates(subset="Order ID")

# %%
superstore2["Order ID"].value_counts()
# Out:
# Order ID
# CA-2012-124891     1
# ES-2013-1622008    1
# IN-2014-50228      1
# IN-2014-48275      1
# ID-2013-33477      1
#                   ..
# IN-2014-60469      1
# TU-2014-1370       1
# US-2011-150434     1
# IN-2014-17951      1
# MX-2012-134460     1
# Name: count, Length: 25035, dtype: int64

# %%
superstore2.shape
# Out:
# (25035, 24)

# %% [markdown]
# ### Missing values

# %%
sales.isnull().sum()
# Out:
# Manufacturer               0
# Model                      0
# Sales_in_thousands         0
# four_year_resale_value    36
# Vehicle_type               0
# Price_in_thousands         2
# Engine_size                1
# Horsepower                 1
# Wheelbase                  1
# Width                      1
# Length                     1
# Curb_weight                2
# Fuel_capacity              1
# Fuel_efficiency            3
# Latest_Launch              0
# Power_perf_factor          2
# Car_area                   1
# Price_category             0
# Price_category_2           0
# dtype: int64

# %%
# Dropping all rows wherever we have missing values
sales4 = sales2.dropna()

# %%
sales4.shape
# Out:
# (117, 19)

# %%
# Merging

# %%
Data
# Out:
#     ID      Name     Address
# 0  101     Sibbu       Delhi
# 1  102     Harry       noida
# 2  103      John       noida
# 3  104     Maria    Gurugram
# 4  101     Sibbu       Delhi
# 5  104      John     Kolkata
# 6  107  Hermoine  Vijaynagar
# 7  209     Nebal    Gaziabad

# %%
Hosp = pd.DataFrame({
    "Pat_id": [101,104,108,110,101],
    "Dr": ["Vishwas", "Gupta", "Gupta", "Khan", "Vishvas"],
    "Disease": ["Fever", "Brain issue", "Neuro", "Bone", "Cold"]
})

# %%
# Inner Join
# left Join
# Right Join
# Outer Join

# %%
# pd.merge(left_table, right_table, on="common_column", how = 'inner/left/right/outer')
# pd.merge(left_table, right_table, 
#          left_on="column form left", right_on="column form right", 
#          how = 'inner/left/right/outer')

# %%
Data.head()
# Out:
#     ID   Name   Address
# 0  101  Sibbu     Delhi
# 1  102  Harry     noida
# 2  103   John     noida
# 3  104  Maria  Gurugram
# 4  101  Sibbu     Delhi

# %%
Hosp.head()
# Out:
#    Pat_id       Dr      Disease
# 0     101  Vishwas        Fever
# 1     104    Gupta  Brain issue
# 2     108    Gupta        Neuro
# 3     110     Khan         Bone
# 4     101  Vishvas         Cold

# %%
left_join_Data_Hosp = pd.merge(Data, Hosp, left_on =["ID"],right_on =["Pat_id"], how= "left")

# %%
left_join_Data_Hosp
# Out:
#     ID      Name     Address  Pat_id       Dr      Disease
# 0  101     Sibbu       Delhi   101.0  Vishwas        Fever
# 1  101     Sibbu       Delhi   101.0  Vishvas         Cold
# 2  102     Harry       noida     NaN      NaN          NaN
# 3  103      John       noida     NaN      NaN          NaN
# 4  104     Maria    Gurugram   104.0    Gupta  Brain issue
# 5  101     Sibbu       Delhi   101.0  Vishwas        Fever
# 6  101     Sibbu       Delhi   101.0  Vishvas         Cold
# 7  104      John     Kolkata   104.0    Gupta  Brain issue
# 8  107  Hermoine  Vijaynagar     NaN      NaN          NaN
# 9  209     Nebal    Gaziabad     NaN      NaN          NaN

# %%
right_join_Data_Hosp = pd.merge(Data, Hosp, left_on =["ID"],right_on =["Pat_id"], how= "right")

# %%
right_join_Data_Hosp
# Out:
#       ID   Name   Address  Pat_id       Dr      Disease
# 0  101.0  Sibbu     Delhi     101  Vishwas        Fever
# 1  101.0  Sibbu     Delhi     101  Vishwas        Fever
# 2  104.0  Maria  Gurugram     104    Gupta  Brain issue
# 3  104.0   John   Kolkata     104    Gupta  Brain issue
# 4    NaN    NaN       NaN     108    Gupta        Neuro
# 5    NaN    NaN       NaN     110     Khan         Bone
# 6  101.0  Sibbu     Delhi     101  Vishvas         Cold
# 7  101.0  Sibbu     Delhi     101  Vishvas         Cold

# %%
outer_join_Data_Hosp = pd.merge(Data, Hosp, left_on =["ID"],right_on =["Pat_id"], how= "outer")

# %%
outer_join_Data_Hosp
# Out:
#        ID      Name     Address  Pat_id       Dr      Disease
# 0   101.0     Sibbu       Delhi   101.0  Vishwas        Fever
# 1   101.0     Sibbu       Delhi   101.0  Vishvas         Cold
# 2   101.0     Sibbu       Delhi   101.0  Vishwas        Fever
# 3   101.0     Sibbu       Delhi   101.0  Vishvas         Cold
# 4   102.0     Harry       noida     NaN      NaN          NaN
# 5   103.0      John       noida     NaN      NaN          NaN
# 6   104.0     Maria    Gurugram   104.0    Gupta  Brain issue
# 7   104.0      John     Kolkata   104.0    Gupta  Brain issue
# 8   107.0  Hermoine  Vijaynagar     NaN      NaN          NaN
# 9   209.0     Nebal    Gaziabad     NaN      NaN          NaN
# 10    NaN       NaN         NaN   108.0    Gupta        Neuro
# 11    NaN       NaN         NaN   110.0     Khan         Bone

# %%
# Those who exist in hospital but not in database

# %% [markdown]
# ### Basic Statitics

# %%
# min, max, mean, median, mode var,

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales["Sales_in_thousands"].mean()
# Out:
# 52.99807643312102

# %%
sales["Horsepower"].max()
# Out:
# 450.0

# %%
sales["Price_in_thousands"].min()
# Out:
# 9.235

# %%
sales[sales["Price_in_thousands"] == sales["Price_in_thousands"].min()]
# Out:
#    Manufacturer  Model  Sales_in_thousands  four_year_resale_value  \
# 26    Chevrolet  Metro              21.855                    5.16
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 26    Passenger               9.235          1.0        55.0       93.1
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 26   62.6   149.4        1.895           10.3             45.0     4/13/2012
#
#     Power_perf_factor  Car_area Price_category Price_category_2
# 26          23.276272   9352.44         Normal       Affordable

# %%
sales["Manufacturer"].mode()
# Out:
# 0    Dodge
# 1     Ford
# Name: Manufacturer, dtype: object

# %%
sales["Manufacturer"].value_counts()
# Out:
# Manufacturer
# Dodge         11
# Ford          11
# Toyota         9
# Chevrolet      9
# Mercedes-B     9
# Mitsubishi     7
# Nissan         7
# Chrysler       7
# Volvo          6
# Oldsmobile     6
# Lexus          6
# Mercury        6
# Pontiac        6
# Volkswagen     6
# Saturn         5
# Cadillac       5
# Honda          5
# Plymouth       4
# Acura          4
# Buick          4
# Audi           3
# Jeep           3
# Porsche        3
# Hyundai        3
# BMW            3
# Lincoln        3
# Saab           2
# Subaru         2
# Jaguar         1
# Infiniti       1
# Name: count, dtype: int64

# %%
sales["Sales_in_thousands"].skew() #skewness
# Out:
# 3.408518366470572

# %%
sales["Sales_in_thousands"].kurt()
# Out:
# 17.55734423299965

# %%
sales["Sales_in_thousands"].quantile(.10)
# Out:
# 5.453600000000001

# %%
sales["Sales_in_thousands"].quantile(.95)
# Out:
# 185.3361999999998

# %%
sales[['Price_in_thousands', 'Sales_in_thousands']].mean()
# Out:
# Price_in_thousands    27.390755
# Sales_in_thousands    52.998076
# dtype: float64

# %%
sales.groupby("Vehicle_type")["Price_in_thousands"].mean()
# Out:
# Vehicle_type
# Car          26.319975
# Passenger    27.763200
# Name: Price_in_thousands, dtype: float64

# %%
sales.groupby("Manufacturer")["Sales_in_thousands"].mean()
# Out:
# Manufacturer
# Acura          19.751250
# Audi           13.519000
# BMW            15.501667
# Buick          60.504750
# Cadillac       22.435600
# Chevrolet      61.596111
# Chrysler       28.817286
# Dodge          82.740818
# Ford          183.875909
# Honda         118.534800
# Hyundai        45.775333
# Infiniti       23.713000
# Jaguar         15.467000
# Jeep           97.717667
# Lexus          17.807167
# Lincoln        28.544667
# Mercedes-B     13.013889
# Mercury        39.666500
# Mitsubishi     25.842143
# Nissan         57.090714
# Oldsmobile     29.831500
# Plymouth       16.000250
# Pontiac        61.755667
# Porsche         4.042667
# Saab           10.653000
# Saturn         33.770000
# Subaru         40.067500
# Toyota         82.245000
# Volkswagen     34.868667
# Volvo          12.623333
# Name: Sales_in_thousands, dtype: float64

# %%
sales.groupby("Manufacturer")["Sales_in_thousands"].min()
# Out:
# Manufacturer
# Acura          8.588
# Audi           1.380
# BMW            9.231
# Buick         27.851
# Cadillac       6.536
# Chevrolet     17.947
# Chrysler       7.854
# Dodge          0.916
# Ford          35.068
# Honda         12.855
# Hyundai       29.450
# Infiniti      23.713
# Jaguar        15.467
# Jeep          55.557
# Lexus          3.334
# Lincoln       13.798
# Mercedes-B     0.954
# Mercury       14.351
# Mitsubishi     0.110
# Nissan        27.308
# Oldsmobile     1.112
# Plymouth       1.872
# Pontiac       19.911
# Porsche        1.280
# Saab           9.191
# Saturn         5.223
# Subaru        33.028
# Toyota         9.835
# Volkswagen     5.596
# Volvo          3.493
# Name: Sales_in_thousands, dtype: float64

# %%
sales.groupby("Manufacturer").agg({
    "Price_in_thousands": ["min", "max", "mean", "count"],
    "Sales_in_thousands": ["min", "max"],
})
# Out:
#              Price_in_thousands                          Sales_in_thousands  \
#                             min     max       mean count                min
# Manufacturer
# Acura                    21.500  42.000  30.633333     3              8.588
# Audi                     23.990  62.000  39.980000     3              1.380
# BMW                      26.990  38.900  33.096667     3              9.231
# Buick                    21.975  31.965  26.781250     4             27.851
# Cadillac                 31.010  46.225  40.254000     5              6.536
# Chevrolet                 9.235  45.705  20.022778     9             17.947
# Chrysler                 16.480  29.185  23.430833     6              7.854
# Dodge                    12.640  69.725  24.213636    11              0.916
# Ford                     12.050  36.135  21.047273    11             35.068
# Honda                    12.885  26.600  20.277000     5             12.855
# ...

# %%
sales.groupby(["Manufacturer", "Vehicle_type"]).agg({
    "Price_in_thousands": ["min", "max", "mean", "count"],
    "Sales_in_thousands": ["min", "max"],
})
# Out:
#                           Price_in_thousands                           \
#                                          min     max       mean count
# Manufacturer Vehicle_type
# Acura        Passenger                21.500  42.000  30.633333     3
# Audi         Passenger                23.990  62.000  39.980000     3
# BMW          Passenger                26.990  38.900  33.096667     3
# Buick        Passenger                21.975  31.965  26.781250     4
# Cadillac     Car                      46.225  46.225  46.225000     1
#              Passenger                31.010  44.475  38.761250     4
# Chevrolet    Passenger                 9.235  45.705  20.022778     9
# Chrysler     Car                         NaN     NaN        NaN     0
#              Passenger                16.480  29.185  23.430833     6
# Dodge        Car                      16.980  26.310  20.367500     6
#              Passenger                12.640  69.725  28.829000     5
# ...

# %% [markdown]
# ### Plots

# %%
# Bar
sales["Vehicle_type"].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
sales["Vehicle_type"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Vehicle_type'>

# %%
sales["Vehicle_type"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  four_year_resale_value  \
# 0        Acura  Integra              16.919                  16.360
# 1        Acura       TL              39.384                  19.875
# 2        Acura       CL              14.114                  18.225
# 3        Acura       RL               8.588                  29.725
# 4         Audi       A4              20.397                  22.255
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0    Passenger               21.50          1.8       140.0      101.2   67.3
# 1    Passenger               28.40          3.2       225.0      108.1   70.3
# 2    Passenger                 NaN          3.2       225.0      106.9   70.6
# 3    Passenger               42.00          3.5       210.0      114.6   71.4
# 4    Passenger               23.99          1.8       150.0      102.6   68.2
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %%
sales.plot.scatter(x="Sales_in_thousands", y="four_year_resale_value", s=25)
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='four_year_resale_value'>
